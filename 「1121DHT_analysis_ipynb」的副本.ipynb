# %% [markdown]
# <a href="https://colab.research.google.com/github/husthorng/ML/blob/main/%E3%80%8C1121DHT_analysis_ipynb%E3%80%8D%E7%9A%84%E5%89%AF%E6%9C%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tables.table import Column
#write2sheet_plot.ipynb
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from datetime import datetime
df = pd.read_excel('https://docs.google.com/spreadsheets/d/e/2PACX-1vSmD93wvf4VVYgJ_KRd1jX_XlF0k33TeqW5kh70WN90C7u060lmu5X1xOaZpkBibOd92vblUtJjd6b7/pub?output=xlsx')
df['hours']=df['Date '].dt.hour
#print(df.iloc[-1,:]['Date ']) #最後一筆
df['Time']=pd.to_datetime(df['Time'], format='%H:%M:%S')
start_datetime = pd.Timestamp('2023-08-29 13:00:00')


da=(df['Date '])-(start_datetime)
#time_interval = pd.Timedelta(da)

print("aad=",da)

#print(time_interval.components.days)
#print(time_interval.components.hours)
hours = time_interval.components.hours+da.days*24



# 設定第一個日期時間
start_time = pd.to_datetime("2023/08/29, 13:00:00")

# 設定第二個日期時間
end_time = pd.to_datetime("2023/08/30, 12:59:59")
selb1=df[(df['Date ']>start_time) & (df['Date ']< end_time)]

selb1.reset_index(inplace=True)




selb1.loc[:,'hours']=(selb1.loc[:,'Date '])-(start_datetime)
print(selb1.dtypes)
#selb1.loc[1,'hours']
time_val=(selb1.loc[:,'hours'])
#print(time_val)
i=0
#for row in time_val:
#  print("1")
time_val[1].components.hours
print("aaaa=",time_val)




#for row in selb1.loc[:,'hours'] :
#  print(pd.Timedelta(selb1.loc[:,'hours']))


# 計算總時數
time_difference = end_time - start_time

# 提取總時數的小時部分
total_hours = time_difference.total_seconds() / 3600

print("總時數（僅取時數值）:", int(total_hours))


print("小时数:", hours)
print(da)
print(da.value)
print(da.days*24)

#df['hours']=df['Time'].dt.hour
#print(df)


#print(selb1)
Dmean=selb1.groupby('hours')[['Temperature','Humidity','PhotomV']].mean()
Dstd=selb1.groupby('hours')[['Temperature','Humidity','PhotomV']].std()
print(Dmean)
print(Dstd)
# Out:
# aad= 0      2 days 04:40:45
# 1      2 days 04:11:43
# 2      2 days 04:10:34
# 3      2 days 04:09:24
# 4      2 days 04:08:15
#              ...
# 2659   0 days 00:28:54
# 2660   0 days 00:27:44
# 2661   0 days 00:26:35
# 2662   0 days 00:25:24
# 2663   0 days 00:24:15
# Name: Date , Length: 2664, dtype: timedelta64[ns]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-16c72fb37b55> in <cell line: 22>()
#      20 #print(time_interval.components.days)
#      21 #print(time_interval.components.hours)
# ---> 22 hours = time_interval.components.hours+da.days*24
#      23
#      24
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#    5903
# ...

# %%
((24+8)*60+25)*60+15
# Out:
# 116715

# %%
dfc = pd.DataFrame({'a': ['one', 'one', 'two',
                          'three', 'two', 'one', 'six'],
                    'c': np.arange(7)})


dfd = dfc.copy()
dfd.rename(columns = {'a':'AA'}, inplace = True)
result = pd.concat([dfc, dfd], axis=1)

# %%
result
# Out:
#        a  c     AA  c
# 0    one  0    one  0
# 1    one  1    one  1
# 2    two  2    two  2
# 3  three  3  three  3
# 4    two  4    two  4
# 5    one  5    one  5
# 6    six  6    six  6
